# %% [markdown]
# # Police Killings in the US - Exploratory Data Analysis

# %% [markdown]
# - The ultimate goal for this project is to use demographics and shooting data to predict the race of victims of fatal police shootings in the US.
# - This notebook will focus on the following task:
# 	-  Exploratory data analysis
# - The following notebook, "Classification_Model", will focus on building the actual model to make predictions.

# %% [markdown]
# # Load in Dataframe from "SQL_EDA" Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import datetime as dt

# %%
with open('Data/sql_demo_killings_df.pkl','rb') as read_file:
    demo_killings_df = pickle.load(read_file)

# %% [markdown]
# # EDA

# %% [markdown]
# The classifier model will be built to determine if a victim is white or a POC. Therefore, the overall race distribution will be compared to the race distribution for each feature. The following question needs to be asked:
# - **Are there any trends that make race more predictable for each shooting?**
# - i.e. what makes police more likely to kill POC?

# %% [markdown]
# **Other questions to ask**
# - What are the demographics of the cities with the most police killings?
#     - How does this compare with the rest of the cities?
# - What is the correlation between poverty_rate and median_income?
# - What is the correlation between poverty_rate and percent_completed_hs?

# %% [markdown]
# ---

# %% [markdown]
# The results below will inform how the classifier model is built in the next notebook.

# %% [markdown]
# ---

# %% [markdown]
# ## Overall Race Distribution and Correlations

# %%
plt.bar(demo_killings_df.race.value_counts().index, demo_killings_df.race.value_counts().values)
plt.title('Overall Race Distribution')
plt.show()

# %%
def correlations(df):

    return df[['year', 'age','poverty_rate', 'percent_completed_hs', 'share_white', 'share_black',
               'share_native_american', 'share_asian', 'share_hispanic', 'median_income']].corr().style.background_gradient()

# %%
correlations(demo_killings_df)
# Out:
# <style  type="text/css" >
#     #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col4 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col5 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col6 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col7 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col8 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow0_col9 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col2 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col3 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col4 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col5 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col6 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col8 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow1_col9 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col3 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col4 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col5 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col6 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col8 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col5 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col6 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col7 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow3_col9 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col3 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col8 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow4_col9 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col3 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col7 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col8 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_26456746_b1c6_11ea_9461_88e9fe790f6erow5_col9 {
#             background-color:  #c9cee4;
#             color:  #000000;

# %% [markdown]
# ## Race Distributions

# %%
def race_distribution(df, column):
    
    for item in df[column].value_counts().index:
        plt.bar(df[df[column] == item].race.value_counts().index, df[df[column] == item].race.value_counts().values)
        plt.title('Race Distribution - ' + str(item))
        plt.show()

# %% [markdown]
# ### Region

# %% [markdown]
# - Victims on the West and East Coasts are disproportionately POC.
#     - However, this is likely due to demographics

# %%
demo_killings_df.region.value_counts()
# Out:
# South         867
# West Coast    493
# Mountain      335
# Midwest       325
# Northeast     188
# Central        64
# Other          20
# Name: region, dtype: int64

# %%
race_distribution(demo_killings_df, 'region')

# %% [markdown]
# ### City Type

# %% [markdown]
# - Victims in any type that is not a city are disproportionately white

# %%
race_distribution(demo_killings_df, 'city_type')

# %% [markdown]
# ### Mental Illness

# %% [markdown]
# - Victims with signs of mental illness are disproportionately white.

# %%
race_distribution(demo_killings_df, 'signs_of_mental_illness')

# %% [markdown]
# ### Threat Level

# %% [markdown]
# - Victims with an "undetermined" threat level are disproportionately POC.

# %%
race_distribution(demo_killings_df, 'threat_level')

# %% [markdown]
# ### Fleeing

# %% [markdown]
# - Victims who are fleeing by foot are disproportionately POC.

# %%
race_distribution(demo_killings_df, 'flee')

# %% [markdown]
# ### Armed vs Unarmed

# %% [markdown]
# - Unarmed victims are disproportionately POC.

# %%
demo_killings_df.armed.value_counts()
# Out:
# gun                  1273
# sharp object          398
# unarmed               182
# vehicle               159
# undetermined          140
# non-lethal object      95
# blunt object           45
# Name: armed, dtype: int64

# %%
race_distribution(demo_killings_df, 'armed')

# %% [markdown]
# ### Body Cameras

# %% [markdown]
# - No discernable difference

# %%
race_distribution(demo_killings_df, 'body_camera')

# %% [markdown]
# ### Month vs Season

# %% [markdown]
# - No discernable differences among seasons

# %%
race_distribution(demo_killings_df, 'month')

# %% [markdown]
# ### Weekday vs Day of Week

# %% [markdown]
# - Victims on Thursdays are disproportionately POC.

# %%
race_distribution(demo_killings_df, 'day_of_week')

# %% [markdown]
# ---

# %%
def eda_charts(df):
    
    plt.bar(df.race.value_counts().index, df.race.value_counts().values)
    plt.title('Police Killings by Race')
    plt.show()
    
    plt.hist(df.poverty_rate)
    plt.title('Poverty Rate Distribution (%)')
    plt.show()
    
    plt.hist(df.percent_completed_hs)
    plt.title('High School Completion (% of Population) Distribution')
    plt.show()
    
    plt.hist(df.median_income)
    plt.title('Median Income Distribution')
    plt.show()

# %% [markdown]
# ## Top 32 Cities

# %% [markdown]
# - POC are disproportionately killed in the cities with the most police shootings.

# %%
most_killings_df = demo_killings_df.loc[demo_killings_df['city'].isin(demo_killings_df.city.value_counts().index[:32])]

# %%
correlations(most_killings_df)
# Out:
# <style  type="text/css" >
#     #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col3 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col4 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col5 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col6 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col7 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col8 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow0_col9 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col2 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col3 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col4 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col5 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col6 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col7 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col8 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow1_col9 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col6 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col7 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col8 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col4 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col5 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col6 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col7 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow3_col9 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col2 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col6 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col8 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow4_col9 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col2 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col3 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col7 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col8 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_2a0731a2_b1c6_11ea_9461_88e9fe790f6erow5_col9 {
#             background-color:  #c2cbe2;
#             color:  #000000;

# %%
eda_charts(most_killings_df)

# %% [markdown]
# ## Rest of Cities

# %%
rest_killings_df = demo_killings_df.loc[demo_killings_df['city'].isin(demo_killings_df.city.value_counts().index[32:])]

# %%
correlations(rest_killings_df)
# Out:
# <style  type="text/css" >
#     #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col1 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col3 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col4 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col5 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col7 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col8 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow0_col9 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col2 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col3 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col4 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col5 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col6 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col7 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col8 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow1_col9 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col4 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col5 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col6 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col7 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col8 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col5 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col6 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col7 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow3_col9 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col8 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow4_col9 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col2 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col6 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col7 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col8 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_2a5fa580_b1c6_11ea_9461_88e9fe790f6erow5_col9 {
#             background-color:  #c9cee4;
#             color:  #000000;

# %%
eda_charts(rest_killings_df)
